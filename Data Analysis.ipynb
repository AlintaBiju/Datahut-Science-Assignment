# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\Web Scraping\limeroad_men_casualshirts.csv")

# %%
df
# Out:
#                                           Product Name           Brand  \
# 0               Men Navy Blue Regular Fit Casual Shirt            Wuxi
# 1    Men Navy Regular Fit Solid Short Sleeved Casua...   Beyou Fashion
# 2              Men Collared Short Sleeves Casual Shirt       Unlimited
# 3                              Mens Solid Casual Shirt       Vida Loca
# 4                             Mens Checks Casual Shirt         D Kumar
# ..                                                 ...             ...
# 305  Men Checkered Long Sleeve Regular Fit Casual S...       Showoffff
# 306    Men Solid Short Sleeve Regular Fit Casual Shirt       Showoffff
# 307  Men Checkered Long Sleeve Regular Fit Casual S...       Showoffff
# 308  Men Checkered Long Sleeve Regular Fit Casual S...       Showoffff
# 309               Men Striped Long Sleeve Casual Shirt       Showoffff
#
#                 Category   MRP  Discounted Price  Rating  \
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 305    False
# 306    False
# 307    False
# 308    False
# 309    False
# Length: 310, dtype: bool

# %%
pd.set_option("display.max_rows",None)

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product Name      310 non-null    object
#  1   Brand             310 non-null    object
#  2   Category          310 non-null    object
#  3   MRP               310 non-null    int64
#  4   Discounted Price  310 non-null    int64
#  5   Rating            310 non-null    float64
#  6   Product URL       310 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 17.1+ KB

# %%
df.describe()
# Out:
#                MRP  Discounted Price      Rating
# count   310.000000        310.000000  310.000000
# mean   1652.483871        675.519355    4.162903
# std     720.124880        275.347038    0.456961
# min     299.000000        236.000000    2.500000
# 25%     999.000000        449.250000    4.000000
# 50%    1624.000000        679.000000    4.000000
# 75%    2398.000000        849.000000    4.500000
# max    3040.000000       1579.000000    5.000000

# %%
df['Brand'].unique()
# Out:
# array([' Wuxi', ' Beyou Fashion', ' Unlimited', ' Vida Loca', ' D Kumar',
#        ' Flick By Vmart', ' Xatia', ' V-Mart', ' Ketch', ' Limeroad',
#        ' Jwhite By Vmart', ' Meghz', ' Indo Cotton', ' Showoffff',
#        ' Millennial Men', ' Cape Canary', ' Jainish', ' Crosscreek',
#        ' Am Swan', ' Twenty Eight', ' Chimpaaanzee', ' Printcultr',
#        ' Vs Mall', ' Indian Needle', ' Allan Peter', ' Styli', ' Enspyr',
#        ' Purple State', ' Sand Dunes', ' Oxolloxo', ' Duke',
#        ' Brown Brothers', ' Leotude', ' Neef Play', ' Ambi',
#        ' Ethnic Treasures', ' Showoff Plus', ' All Ways You',
#        ' Veera Paridhaan', ' Ad By Arvind', ' Dimeh'], dtype=object)

# %%
df['Brand'].value_counts()
# Out:
# Brand
# Showoffff           78
# Ketch               67
# V-Mart              30
# Flick By Vmart      23
# Beyou Fashion       17
# Duke                 7
# Am Swan              7
# Indo Cotton          6
# Vida Loca            5
# Enspyr               4
# Twenty Eight         4
# Jainish              4
# Cape Canary          4
# Chimpaaanzee         4
# Indian Needle        4
# Brown Brothers       4
# Limeroad             4
# Purple State         3
# D Kumar              3
# Unlimited            3
# Allan Peter          3
# Sand Dunes           2
# Neef Play            2
# Wuxi                 2
# Vs Mall              2
# Xatia                2
# Crosscreek           2
# Ad By Arvind         1
# Veera Paridhaan      1
# All Ways You         1
# Showoff Plus         1
# Ethnic Treasures     1
# Ambi                 1
# Leotude              1
# Styli                1
# Jwhite By Vmart      1
# Meghz                1
# Oxolloxo             1
# Millennial Men       1
# ...

# %%
df['Discounted_percentage'] = ((df['MRP'] - df['Discounted Price']) / df['MRP']) * 100

# %%
avg_dis = df.groupby('Brand')['Discounted_percentage'].mean()

# %%
avg_dis.sort_values(ascending = False)
# Out:
# Brand
# Ambi                82.993701
# All Ways You        81.511671
# Xatia               81.141163
# Purple State        80.468072
# Oxolloxo            76.409945
# Printcultr          76.314565
# Wuxi                73.070782
# Ketch               72.549370
# Indo Cotton         71.988796
# Styli               71.090047
# Meghz               67.533767
# Jainish             67.139675
# Showoff Plus        67.138158
# Allan Peter         66.698242
# Showoffff           64.363268
# Vida Loca           61.624650
# Indian Needle       61.457960
# Crosscreek          60.451128
# Neef Play           58.858152
# Millennial Men      58.365759
# Beyou Fashion       58.287699
# Brown Brothers      57.736721
# Cape Canary         53.846012
# D Kumar             53.365676
# Am Swan             52.112380
# Veera Paridhaan     50.583658
# Vs Mall             50.207980
# Ad By Arvind        48.353481
# Chimpaaanzee        47.981693
# Enspyr              42.870982
# Leotude             42.766151
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df['MRP'], bins=30, kde=False, color='skyblue')
plt.title('Distribution of Product Prices (MRP)')
plt.xlabel('Price')
plt.ylabel('Number of Products')
plt.savefig('product_MRP_distribution.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
sns.histplot(df['Discounted Price'], bins=30, kde=False, color='royalblue')
plt.title('Distribution of Product Prices (Discounted price)')
plt.xlabel('Discounted Price')
plt.ylabel('Number of Products')
plt.savefig('product_disountprice_distribution.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x= 'Brand',y = 'Avg_Discount_By_Brand',data=df,color='indianred',edgecolor='black')
plt.xlabel("Brand")
plt.ylabel("Avg Discount by Brand")
plt.title("Average discount percentage by brand")
plt.xticks(rotation = 90,ha = 'right')
plt.savefig("avg_discount_percentage_by_brand.png",dpi=300,bbox_inches='tight')
plt.show()

# %%
df['Avg_Discount_By_Brand'] = df['Brand'].map(avg_dis)

# %%
df
# Out:
#                                           Product Name           Brand  \
# 0               Men Navy Blue Regular Fit Casual Shirt            Wuxi
# 1    Men Navy Regular Fit Solid Short Sleeved Casua...   Beyou Fashion
# 2              Men Collared Short Sleeves Casual Shirt       Unlimited
# 3                              Mens Solid Casual Shirt       Vida Loca
# 4                             Mens Checks Casual Shirt         D Kumar
# ..                                                 ...             ...
# 305  Men Checkered Long Sleeve Regular Fit Casual S...       Showoffff
# 306    Men Solid Short Sleeve Regular Fit Casual Shirt       Showoffff
# 307  Men Checkered Long Sleeve Regular Fit Casual S...       Showoffff
# 308  Men Checkered Long Sleeve Regular Fit Casual S...       Showoffff
# 309               Men Striped Long Sleeve Casual Shirt       Showoffff
#
#                 Category   MRP  Discounted Price  Rating  \
# ...

# %%
sns.boxplot(x='Category', y='MRP', data=df, color='lightseagreen')
plt.title('Price Distribution for category')
plt.ylabel('MRP')
plt.savefig("MRPprice_distribution_for_Mens_casual_shirts.png",dpi=300, bbox_inches='tight')
plt.show()

# %%
sns.boxplot(x='Category', y='Discounted Price', data=df, color='orange')
plt.title('Price Distribution for category')
plt.ylabel('Discounted Price')
plt.savefig("discountprice_distribution_for_Mens_casual_shirts.png",dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(df['Discounted_percentage'], df['Rating'], alpha=0.5, color='blue')
plt.title('Ratings vs Discount Percentage')
plt.xlabel('Discount Percentage')
plt.ylabel('Rating')
plt.grid(True,alpha = 0.2)
plt.savefig("rating_vs_discountpercentage.png",dpi=300, bbox_inches='tight')
plt.show()
